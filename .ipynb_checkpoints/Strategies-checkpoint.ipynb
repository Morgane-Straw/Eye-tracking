# %%
import pandas as pd
df=pd.read_csv('trajectories_data.csv').drop(['Unnamed: 0'], axis=1)

# %%
import json
with open('traj.json') as json_file:
    traj = json.load(json_file)

# %%
for c in traj:
    for r in traj[c]:
        for q in traj[c][r]:
            traj[c][r][q]={eval(k): traj[c][r][q][k] for k in traj[c][r][q]}

# %%
with open('aoi/aoi_gaze.json') as json_file:
    aoi_gaze = json.load(json_file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-f7b37aaf3e2a> in <module>
# ----> 1 with open('aoi/aoi_gaze.json') as json_file:
#       2     aoi_gaze = json.load(json_file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'aoi/aoi_gaze.json'

# %%
traj0=[(aoi_gaze[c][r][q][i],aoi_gaze[c][r][q][i+1]) for i in range(len(aoi_gaze[c][r][q])-1) if (aoi_gaze[c][r][q][i]!=aoi_gaze[c][r][q][i+1]) ]
# Out:
# {'c1': {'r1': {'q1': {(0, 'enonce5'): 1,
#     ('enonce5', 'enonce6'): 1,
#     ('enonce6', 'reponses10'): 1,
#     ('reponses10', 'enonce2'): 1,
#     ('enonce2', 'enonce5'): 1,
#     ('enonce5', 'enonce8'): 1,
#     ('enonce8', 'enonce6'): 1,
#     ('enonce6', 'enonce3'): 1,
#     ('enonce3', 'enonce6'): 1,
#     ('enonce6', 'reponses13'): 1,
#     ('reponses13', 'reponses14'): 1,
#     ('reponses14', 'reponses15'): 1,
#     ('reponses15', 'bonne reponse'): 1,
#     ('bonne reponse', 'enonce6'): 1,
#     ('enonce3', 'reponses14'): 1,
#     ('reponses14', 'reponses13'): 1,
#     ('reponses13', 'reponses10'): 1,
#     ('reponses10', 'reponses11'): 1,
#     ('reponses11', 'bonne reponse'): 1,
#     ('bonne reponse', 'reponses11'): 1,
#     ('reponses11', 'enonce9'): 1,
#     ('enonce9', 'enonce8'): 1,
#     ('enonce8', 'enonce9'): 1,
#     ('enonce9', 'reponses13'): 1,
#     ('reponses13', 'reponses11'): 1,
#     ('reponses11', 'reponses10'): 1,
#     ('reponses10', 'enonce6'): 1,
# ...
